# %%
import pandas as pd
df =pd.read_csv(r'C:\Users\jjann\OneDrive\DATA SCIENCE PROJECT\diabetic prediction\diabetes_risk.csv')

# %%
print(df)
# Out:
#        patient_id  age  gender       city   bmi family_history_diabetes  \
# 0               1   47  Female     Mumbai  26.5                     Yes
# 1               2   53  Female     Mumbai  20.5                     Yes
# 2               3   47    Male      Thane  31.3                      No
# 3               4   41    Male  Bengaluru  22.8                      No
# 4               5   57  Female  Bengaluru  16.7                      No
# ...           ...  ...     ...        ...   ...                     ...
# 14995       14996   47    Male     Mumbai  37.7                      No
# 14996       14997   48  Female     Mumbai  20.6                      No
# 14997       14998   34  Female     Nagpur  17.9                      No
# 14998       14999   56    Male  Ahmedabad  20.7                     Yes
# 14999       15000   54    Male      Surat  34.5                      No
#
#       physical_activity_level       diet_type smoking_status  \
# 0                   Sedentary      Vegetarian          Never
# 1                    Moderate      Vegetarian          Never
# 2                    Moderate  Non-Vegetarian        Current
# 3                   Sedentary  Non-Vegetarian          Never
# 4                   Sedentary  Non-Vegetarian        Current
# ...                       ...             ...            ...
# 14995               Sedentary  Non-Vegetarian          Never
# 14996                Moderate  Non-Vegetarian          Never
# 14997                  Active      Vegetarian          Never
# 14998                  Active      Vegetarian          Never
# 14999                Moderate      Vegetarian          Never
#
#       alcohol_consumption  hours_sleep_per_night  stress_level  \
# 0                   Never                    9.0             8
# 1                   Never                    7.0             6
# 2                 Regular                    7.0             7
# 3                   Never                    9.0             5
# 4              Occasional                    6.5            10
# ...                   ...                    ...           ...
# 14995               Never                    6.8             7
# 14996                 NaN                    6.0             8
# 14997               Never                    7.0             6
# 14998               Never                    6.0             5
# 14999               Never                    7.4             2
#
#        fasting_blood_sugar  hba1c_level  blood_pressure_systolic  \
# 0                      178          7.3                      146
# 1                      152          6.9                      156
# 2                      168          6.6                      150
# 3                      155          6.7                      126
# 4                      188          6.7                      130
# ...                    ...          ...                      ...
# 14995                  213          8.1                      150
# 14996                  162          6.5                      132
# 14997                  137          6.5                      136
# 14998                  163          6.9                      140
# 14999                  186          7.2                      150
#
#        blood_pressure_diastolic  waist_circumference_cm income_bracket  \
# 0                            90                   107.1           High
# 1                           100                    93.8            Low
# 2                           102                   113.5            Low
# 3                            92                   109.6         Middle
# 4                            90                    80.8           High
# ...                         ...                     ...            ...
# 14995                       100                   141.7           High
# 14996                        80                    91.0            NaN
# 14997                        90                    88.8            Low
# 14998                        87                    94.8            Low
# 14999                        88                   130.4         Middle
#
#       diabetes_risk
# 0               Low
# 1               Low
# 2              High
# 3               Low
# 4               Low
# ...             ...
# 14995          High
# 14996           Low
# 14997           Low
# 14998           Low
# 14999      Moderate
#
# [15000 rows x 19 columns]

# %%
df.head(10)
# Out:
#    patient_id  age  gender       city   bmi family_history_diabetes  \
# 0           1   47  Female     Mumbai  26.5                     Yes
# 1           2   53  Female     Mumbai  20.5                     Yes
# 2           3   47    Male      Thane  31.3                      No
# 3           4   41    Male  Bengaluru  22.8                      No
# 4           5   57  Female  Bengaluru  16.7                      No
# 5           6   58    Male  Hyderabad  22.0                      No
# 6           7   42  Female  Hyderabad  22.5                      No
# 7           8   42  Female      Delhi  19.5                      No
# 8           9   57    Male     Mumbai  20.3                     Yes
# 9          10   44    Male     Mumbai  24.1                      No
#
#   physical_activity_level       diet_type smoking_status alcohol_consumption  \
# 0               Sedentary      Vegetarian          Never               Never
# 1                Moderate      Vegetarian          Never               Never
# 2                Moderate  Non-Vegetarian        Current             Regular
# 3               Sedentary  Non-Vegetarian          Never               Never
# 4               Sedentary  Non-Vegetarian        Current          Occasional
# 5                  Active  Non-Vegetarian          Never          Occasional
# 6               Sedentary  Non-Vegetarian            NaN                 NaN
# 7                  Active  Non-Vegetarian          Never               Never
# 8                Moderate  Non-Vegetarian        Current               Never
# 9                Moderate  Non-Vegetarian        Current          Occasional
#
#    hours_sleep_per_night  stress_level  fasting_blood_sugar  hba1c_level  \
# 0                    9.0             8                  178          7.3
# 1                    7.0             6                  152          6.9
# 2                    7.0             7                  168          6.6
# 3                    9.0             5                  155          6.7
# 4                    6.5            10                  188          6.7
# 5                    6.9             6                  148          6.3
# 6                    7.0            10                  190          7.5
# 7                    6.0             7                  270          8.9
# 8                    4.8            10                  186          7.4
# 9                    6.2             8                  178          7.6
#
#    blood_pressure_systolic  blood_pressure_diastolic  waist_circumference_cm  \
# 0                      146                        90                   107.1
# 1                      156                       100                    93.8
# 2                      150                       102                   113.5
# 3                      126                        92                   109.6
# 4                      130                        90                    80.8
# 5                      148                       100                    98.0
# 6                      140                        81                    95.0
# 7                      136                        80                    89.9
# 8                      170                        91                    92.3
# 9                      150                        90                   102.5
#
#   income_bracket diabetes_risk
# 0           High           Low
# 1            Low           Low
# 2            Low          High
# 3         Middle           Low
# 4           High           Low
# 5           High           Low
# 6           High      Moderate
# 7         Middle          High
# 8           High      Moderate
# 9           High      Moderate

# %%
df.tail(10 )
# Out:
#        patient_id  age  gender       city   bmi family_history_diabetes  \
# 14990       14991   35    Male  Bengaluru  32.7                      No
# 14991       14992   55    Male  Bengaluru  15.0                      No
# 14992       14993   58  Female      Surat  22.3                      No
# 14993       14994   44  Female  Hyderabad  29.9                      No
# 14994       14995   59  Female     Mumbai  24.3                     Yes
# 14995       14996   47    Male     Mumbai  37.7                      No
# 14996       14997   48  Female     Mumbai  20.6                      No
# 14997       14998   34  Female     Nagpur  17.9                      No
# 14998       14999   56    Male  Ahmedabad  20.7                     Yes
# 14999       15000   54    Male      Surat  34.5                      No
#
#       physical_activity_level       diet_type smoking_status  \
# 14990                Moderate  Non-Vegetarian          Never
# 14991                  Active      Vegetarian          Never
# 14992                  Active  Non-Vegetarian          Never
# 14993               Sedentary      Vegetarian          Never
# 14994                Moderate      Vegetarian         Former
# 14995               Sedentary  Non-Vegetarian          Never
# 14996                Moderate  Non-Vegetarian          Never
# 14997                  Active      Vegetarian          Never
# 14998                  Active      Vegetarian          Never
# 14999                Moderate      Vegetarian          Never
#
#       alcohol_consumption  hours_sleep_per_night  stress_level  \
# 14990          Occasional                    8.0             8
# 14991          Occasional                    7.0             8
# 14992                 NaN                    5.0             6
# 14993                 NaN                    6.9             6
# 14994               Never                    8.2             6
# 14995               Never                    6.8             7
# 14996                 NaN                    6.0             8
# 14997               Never                    7.0             6
# 14998               Never                    6.0             5
# 14999               Never                    7.4             2
#
#        fasting_blood_sugar  hba1c_level  blood_pressure_systolic  \
# 14990                  150          6.5                      152
# 14991                  149          6.7                      140
# 14992                  125          6.4                      147
# 14993                  178          7.0                      130
# 14994                  156          6.4                      170
# 14995                  213          8.1                      150
# 14996                  162          6.5                      132
# 14997                  137          6.5                      136
# 14998                  163          6.9                      140
# 14999                  186          7.2                      150
#
#        blood_pressure_diastolic  waist_circumference_cm income_bracket  \
# 14990                        92                   131.0         Middle
# 14991                        90                    82.0           High
# 14992                        80                    96.0         Middle
# 14993                        80                   115.7         Middle
# 14994                       100                    99.6            Low
# 14995                       100                   141.7           High
# 14996                        80                    91.0            NaN
# 14997                        90                    88.8            Low
# 14998                        87                    94.8            Low
# 14999                        88                   130.4         Middle
#
#       diabetes_risk
# 14990      Moderate
# 14991           Low
# 14992           Low
# 14993           Low
# 14994           Low
# 14995          High
# 14996           Low
# 14997           Low
# 14998           Low
# 14999      Moderate

# %%
df.shape
# Out:
# (15000, 19)

# %%
df.describe()
# Out:
#          patient_id           age           bmi  hours_sleep_per_night  \
# count  15000.000000  15000.000000  15000.000000           15000.000000
# mean    7500.500000     44.333667     23.062260               7.309860
# std     4330.271354     10.383753      4.046391               1.109372
# min        1.000000     18.000000     15.000000               3.000000
# 25%     3750.750000     38.000000     20.100000               6.700000
# 50%     7500.500000     45.000000     22.700000               7.000000
# 75%    11250.250000     52.000000     25.600000               8.000000
# max    15000.000000     80.000000     40.800000              12.000000
#
#        stress_level  fasting_blood_sugar   hba1c_level  \
# count  15000.000000         15000.000000  15000.000000
# mean       5.941200           168.789933      6.878387
# std        2.148406            38.365822      0.843276
# min        1.000000            72.000000      4.800000
# 25%        4.000000           145.000000      6.300000
# 50%        6.000000           165.000000      6.800000
# 75%        7.000000           189.000000      7.300000
# max       10.000000           400.000000     13.400000
#
#        blood_pressure_systolic  blood_pressure_diastolic  \
# count             15000.000000              15000.000000
# mean                139.496200                 86.256933
# std                  12.660785                  8.386529
# min                  80.000000                 50.000000
# 25%                 130.000000                 80.000000
# 50%                 140.000000                 88.000000
# 75%                 150.000000                 90.000000
# max                 200.000000                120.000000
#
#        waist_circumference_cm
# count            15000.000000
# mean               100.207933
# std                 10.760331
# min                 73.200000
# 25%                 92.500000
# 50%                 99.300000
# 75%                106.900000
# max                148.200000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   patient_id                15000 non-null  int64
#  1   age                       15000 non-null  int64
#  2   gender                    15000 non-null  str
#  3   city                      15000 non-null  str
#  4   bmi                       15000 non-null  float64
#  5   family_history_diabetes   15000 non-null  str
#  6   physical_activity_level   15000 non-null  str
#  7   diet_type                 15000 non-null  str
#  8   smoking_status            14528 non-null  str
#  9   alcohol_consumption       11212 non-null  str
#  10  hours_sleep_per_night     15000 non-null  float64
#  11  stress_level              15000 non-null  int64
#  12  fasting_blood_sugar       15000 non-null  int64
#  13  hba1c_level               15000 non-null  float64
#  14  blood_pressure_systolic   15000 non-null  int64
#  15  blood_pressure_diastolic  15000 non-null  int64
#  16  waist_circumference_cm    15000 non-null  float64
#  17  income_bracket            14537 non-null  str
#  18  diabetes_risk             15000 non-null  str
# dtypes: float64(4), int64(6), str(9)
# memory usage: 2.9 MB

# %%
df.isnull().sum()
# Out:
# patient_id                     0
# age                            0
# gender                         0
# city                           0
# bmi                            0
# family_history_diabetes        0
# physical_activity_level        0
# diet_type                      0
# smoking_status               472
# alcohol_consumption         3788
# hours_sleep_per_night          0
# stress_level                   0
# fasting_blood_sugar            0
# hba1c_level                    0
# blood_pressure_systolic        0
# blood_pressure_diastolic       0
# waist_circumference_cm         0
# income_bracket               463
# diabetes_risk                  0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(4723)

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14995    False
# 14996    False
# 14997    False
# 14998    False
# 14999    False
# Length: 15000, dtype: bool

# %%
df.columns
# Out:
# Index(['patient_id', 'age', 'gender', 'city', 'bmi', 'family_history_diabetes',
#        'physical_activity_level', 'diet_type', 'smoking_status',
#        'alcohol_consumption', 'hours_sleep_per_night', 'stress_level',
#        'fasting_blood_sugar', 'hba1c_level', 'blood_pressure_systolic',
#        'blood_pressure_diastolic', 'waist_circumference_cm', 'income_bracket',
#        'diabetes_risk'],
#       dtype='str')

# %%
df['diabetes_risk']
# Out:
# 0             Low
# 1             Low
# 2            High
# 3             Low
# 4             Low
#            ...
# 14995        High
# 14996         Low
# 14997         Low
# 14998         Low
# 14999    Moderate
# Name: diabetes_risk, Length: 15000, dtype: str

# %%
df.dtypes
# Out:
# patient_id                    int64
# age                           int64
# gender                          str
# city                            str
# bmi                         float64
# family_history_diabetes         str
# physical_activity_level         str
# diet_type                       str
# smoking_status                  str
# alcohol_consumption             str
# hours_sleep_per_night       float64
# stress_level                  int64
# fasting_blood_sugar           int64
# hba1c_level                 float64
# blood_pressure_systolic       int64
# blood_pressure_diastolic      int64
# waist_circumference_cm      float64
# income_bracket                  str
# diabetes_risk                   str
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop("patient_id", axis=1)

# %%
df.shape
# Out:
# (15000, 18)

# %%
categorical_columns = [
    "smoking_status",
    "alcohol_consumption",
    "income_bracket"
]

for col in categorical_columns:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
df.isnull().sum()
# Out:
# age                         0
# gender                      0
# city                        0
# bmi                         0
# family_history_diabetes     0
# physical_activity_level     0
# diet_type                   0
# smoking_status              0
# alcohol_consumption         0
# hours_sleep_per_night       0
# stress_level                0
# fasting_blood_sugar         0
# hba1c_level                 0
# blood_pressure_systolic     0
# blood_pressure_diastolic    0
# waist_circumference_cm      0
# income_bracket              0
# diabetes_risk               0
# dtype: int64

# %%
for col in categorical_columns:
    print("\n", col)
    print(df[col].value_counts())
# Out:
#  smoking_status
# smoking_status
# Never      10591
# Current     2946
# Former      1463
# Name: count, dtype: int64
#
#  alcohol_consumption
# alcohol_consumption
# Never         9404
# Occasional    4483
# Regular       1113
# Name: count, dtype: int64
#
#  income_bracket
# income_bracket
# Middle    7768
# High      3844
# Low       3388
# Name: count, dtype: int64

# %%
df["diabetes_risk"].value_counts()
# Out:
# diabetes_risk
# Low         9000
# Moderate    3750
# High        2250
# Name: count, dtype: int64

# %%
df["diabetes_risk"].value_counts(normalize=True) * 100
# Out:
# diabetes_risk
# Low         60.0
# Moderate    25.0
# High        15.0
# Name: proportion, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       15000 non-null  int64
#  1   gender                    15000 non-null  str
#  2   city                      15000 non-null  str
#  3   bmi                       15000 non-null  float64
#  4   family_history_diabetes   15000 non-null  str
#  5   physical_activity_level   15000 non-null  str
#  6   diet_type                 15000 non-null  str
#  7   smoking_status            15000 non-null  str
#  8   alcohol_consumption       15000 non-null  str
#  9   hours_sleep_per_night     15000 non-null  float64
#  10  stress_level              15000 non-null  int64
#  11  fasting_blood_sugar       15000 non-null  int64
#  12  hba1c_level               15000 non-null  float64
#  13  blood_pressure_systolic   15000 non-null  int64
#  14  blood_pressure_diastolic  15000 non-null  int64
#  15  waist_circumference_cm    15000 non-null  float64
#  16  income_bracket            15000 non-null  str
#  17  diabetes_risk             15000 non-null  str
# dtypes: float64(4), int64(5), str(9)
# memory usage: 2.8 MB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(7,5))

sns.countplot(data=df, x="diabetes_risk")

plt.title("Distribution of Diabetes Risk")
plt.xlabel("Diabetes Risk")
plt.ylabel("Number of Patients")

plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x="diabetes_risk", y="age")
plt.title("Age vs Diabetes Risk")
plt.xlabel("Diabetes Risk")
plt.ylabel("Age")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x="diabetes_risk", y="bmi")
plt.title("BMI vs Diabetes Risk")
plt.xlabel("Diabetes Risk")
plt.ylabel("BMI")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x="diabetes_risk", y="hba1c_level")
plt.title("HbA1c Level vs Diabetes Risk")
plt.xlabel("Diabetes Risk")
plt.ylabel("HbA1c Level")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x="diabetes_risk", y="fasting_blood_sugar")
plt.title("Fasting Blood Sugar vs Diabetes Risk")
plt.xlabel("Diabetes Risk")
plt.ylabel("Fasting Blood Sugar")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(
    data=df,
    x="family_history_diabetes",
    hue="diabetes_risk"
)
plt.title("Family History vs Diabetes Risk")
plt.xlabel("Family History of Diabetes")
plt.ylabel("Number of Patients")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(
    data=df,
    x="physical_activity_level",
    hue="diabetes_risk"
)
plt.title("Physical Activity Level vs Diabetes Risk")
plt.xlabel("Physical Activity Level")
plt.ylabel("Number of Patients")
plt.show()

# %%
plt.figure(figsize=(12,8))
numeric_df = df.select_dtypes(include="number")
sns.heatmap(
    numeric_df.corr(),
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)
plt.title("Correlation Heatmap")
plt.show()

# %%
df.describe()
# Out:
#                 age           bmi  hours_sleep_per_night  stress_level  \
# count  15000.000000  15000.000000           15000.000000  15000.000000
# mean      44.333667     23.062260               7.309860      5.941200
# std       10.383753      4.046391               1.109372      2.148406
# min       18.000000     15.000000               3.000000      1.000000
# 25%       38.000000     20.100000               6.700000      4.000000
# 50%       45.000000     22.700000               7.000000      6.000000
# 75%       52.000000     25.600000               8.000000      7.000000
# max       80.000000     40.800000              12.000000     10.000000
#
#        fasting_blood_sugar   hba1c_level  blood_pressure_systolic  \
# count         15000.000000  15000.000000             15000.000000
# mean            168.789933      6.878387               139.496200
# std              38.365822      0.843276                12.660785
# min              72.000000      4.800000                80.000000
# 25%             145.000000      6.300000               130.000000
# 50%             165.000000      6.800000               140.000000
# 75%             189.000000      7.300000               150.000000
# max             400.000000     13.400000               200.000000
#
#        blood_pressure_diastolic  waist_circumference_cm
# count              15000.000000            15000.000000
# mean                  86.256933              100.207933
# std                    8.386529               10.760331
# min                   50.000000               73.200000
# 25%                   80.000000               92.500000
# 50%                   88.000000               99.300000
# 75%                   90.000000              106.900000
# max                  120.000000              148.200000

# %%
df.columns
# Out:
# Index(['age', 'gender', 'city', 'bmi', 'family_history_diabetes',
#        'physical_activity_level', 'diet_type', 'smoking_status',
#        'alcohol_consumption', 'hours_sleep_per_night', 'stress_level',
#        'fasting_blood_sugar', 'hba1c_level', 'blood_pressure_systolic',
#        'blood_pressure_diastolic', 'waist_circumference_cm', 'income_bracket',
#        'diabetes_risk'],
#       dtype='str')

# %%
X = df.drop("diabetes_risk", axis=1)
y = df["diabetes_risk"]

# %%
X.dtypes
# Out:
# age                           int64
# gender                          str
# city                          int64
# bmi                         float64
# family_history_diabetes       int64
# physical_activity_level       int64
# diet_type                     int64
# smoking_status                  str
# alcohol_consumption             str
# hours_sleep_per_night       float64
# stress_level                  int64
# fasting_blood_sugar           int64
# hba1c_level                 float64
# blood_pressure_systolic       int64
# blood_pressure_diastolic      int64
# waist_circumference_cm      float64
# income_bracket                  str
# dtype: object

# %%
X.select_dtypes(include="object").columns
# Out:
# C:\Users\jjann\AppData\Local\Temp\ipykernel_23116\2213039483.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   X.select_dtypes(include="object").columns
# Index(['gender', 'smoking_status', 'alcohol_consumption', 'income_bracket'], dtype='str')

# %%
from sklearn.preprocessing import LabelEncoder
categorical_columns = [
    "city",
    "family_history_diabetes",
    "physical_activity_level",
    "diet_type"
]
le = LabelEncoder()
for col in categorical_columns:
    X[col] = le.fit_transform(X[col])

# %%
X.dtypes
# Out:
# age                           int64
# gender                        int64
# city                          int64
# bmi                         float64
# family_history_diabetes       int64
# physical_activity_level       int64
# diet_type                     int64
# smoking_status                int64
# alcohol_consumption           int64
# hours_sleep_per_night       float64
# stress_level                  int64
# fasting_blood_sugar           int64
# hba1c_level                 float64
# blood_pressure_systolic       int64
# blood_pressure_diastolic      int64
# waist_circumference_cm      float64
# income_bracket                int64
# dtype: object

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)
X_scaled.head()
# Out:
#         age    gender      city       bmi  family_history_diabetes  \
# 0  0.256788 -1.023655  0.746380  0.849610                 1.363969
# 1  0.834633 -1.023655  0.746380 -0.633242                 1.363969
# 2  0.256788  0.902923  1.756093  2.035892                -0.733154
# 3 -0.321057  0.902923 -1.273047 -0.064815                -0.733154
# 4  1.219863 -1.023655 -1.273047 -1.572382                -0.733154
#
#    physical_activity_level  diet_type  smoking_status  alcohol_consumption  \
# 0                 1.234003   1.183634        0.611625            -0.711095
# 1                 0.012218   1.183634        0.611625            -0.711095
# 2                 0.012218  -0.883969       -1.883106             2.468642
# 3                 1.234003  -0.883969        0.611625            -0.711095
# 4                 1.234003  -0.883969       -1.883106             0.878774
#
#    hours_sleep_per_night  stress_level  fasting_blood_sugar  hba1c_level  \
# 0               1.523561      0.958324             0.240067     0.499987
# 1              -0.279320      0.027370            -0.437642     0.025631
# 2              -0.279320      0.492847            -0.020590    -0.330136
# 3               1.523561     -0.438107            -0.359445    -0.211547
# 4              -0.730041      1.889277             0.500724    -0.211547
#
#    blood_pressure_systolic  blood_pressure_diastolic  waist_circumference_cm  \
# 0                 0.513714                  0.446334                0.640528
# 1                 1.303580                  1.638762               -0.595534
# 2                 0.829660                  1.877248                1.235325
# 3                -1.066020                  0.684819                0.872871
# 4                -0.750073                  0.446334               -1.803716
#
#    income_bracket
# 0       -1.501800
# 1       -0.311407
# 2       -0.311407
# 3        0.878986
# 4       -1.501800

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42
)
print("X_train:", X_train.shape)
print("X_test:", X_test.shape)
print("y_train:", y_train.shape)
print("y_test:", y_test.shape)
# Out:
# X_train: (12000, 17)
# X_test: (3000, 17)
# y_train: (12000,)
# y_test: (3000,)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(y_pred[:10])
# Out:
# ['Low' 'High' 'Low' 'Low' 'Low' 'Low' 'Low' 'Low' 'Low' 'Moderate']

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8023333333333333

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#         High       0.82      0.75      0.78       432
#          Low       0.86      0.91      0.89      1819
#     Moderate       0.62      0.57      0.60       749
#
#     accuracy                           0.80      3000
#    macro avg       0.77      0.74      0.75      3000
# weighted avg       0.80      0.80      0.80      3000

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[ 322    8  102]
#  [   5 1656  158]
#  [  66  254  429]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)
rf_model.fit(X_train, y_train)
rf_pred = rf_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
rf_accuracy = accuracy_score(y_test, rf_pred)
print("Random Forest Accuracy:", rf_accuracy)
# Out:
# Random Forest Accuracy: 0.803

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#         High       0.82      0.73      0.77       432
#          Low       0.87      0.91      0.89      1819
#     Moderate       0.62      0.58      0.60       749
#
#     accuracy                           0.80      3000
#    macro avg       0.77      0.74      0.75      3000
# weighted avg       0.80      0.80      0.80      3000

# %%
from sklearn.metrics import confusion_matrix
rf_cm = confusion_matrix(y_test, rf_pred)
print(rf_cm)
# Out:
# [[ 314   10  108]
#  [   4 1658  157]
#  [  64  248  437]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(rf_cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Random Forest Confusion Matrix")
plt.show()

# %%
feature_importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": rf_model.feature_importances_
})
feature_importance = feature_importance.sort_values(
    by="Importance",
    ascending=False
)
print(feature_importance)
# Out:
#                      Feature  Importance
# 11       fasting_blood_sugar    0.271162
# 12               hba1c_level    0.231898
# 0                        age    0.075953
# 15    waist_circumference_cm    0.065958
# 3                        bmi    0.065448
# 13   blood_pressure_systolic    0.045379
# 2                       city    0.040274
# 14  blood_pressure_diastolic    0.039061
# 9      hours_sleep_per_night    0.036318
# 10              stress_level    0.033288
# 16            income_bracket    0.015889
# 5    physical_activity_level    0.015645
# 4    family_history_diabetes    0.014061
# 8        alcohol_consumption    0.013419
# 7             smoking_status    0.012760
# 6                  diet_type    0.012515
# 1                     gender    0.010973

# %%
plt.figure(figsize=(10, 6))
sns.barplot(
    data=feature_importance,
    x="Importance",
    y="Feature"
)
plt.title("Feature Importance - Random Forest")
plt.show()

# %%
comparison = pd.DataFrame({
    "Model": ["Logistic Regression", "Random Forest"],
    "Accuracy": [accuracy, rf_accuracy]
})

print(comparison)
# Out:
#                  Model  Accuracy
# 0  Logistic Regression  0.802333
# 1        Random Forest  0.803000

# %%
sns.barplot(
    data=comparison,
    x="Model",
    y="Accuracy"
)
plt.title("Model Accuracy Comparison")
plt.ylim(0, 1)
plt.show()

# %%
import joblib
joblib.dump(rf_model, "diabetes_model.pkl")
# Out:
# ['diabetes_model.pkl']

# %%
import os
print(os.path.exists("diabetes_model.pkl"))
# Out:
# True

# %%
from sklearn.preprocessing import LabelEncoder
import joblib
city_encoder = LabelEncoder()
city_encoder.fit(df["city"])
joblib.dump(city_encoder, "city_encoder.pkl")
# Out:
# ['city_encoder.pkl']

# %%
from sklearn.preprocessing import LabelEncoder
import joblib
categorical_columns = [
    "gender",
    "city",
    "family_history_diabetes",
    "physical_activity_level",
    "diet_type",
    "smoking_status",
    "alcohol_consumption",
    "income_bracket"
]
encoders = {}
for col in categorical_columns:
    encoder = LabelEncoder()
    encoder.fit(df[col].astype(str))
    encoders[col] = encoder
joblib.dump(encoders, "encoders.pkl")
joblib.dump(rf_model, "diabetes_model.pkl")
print("Model and encoders saved successfully!")
# Out:
# Model and encoders saved successfully!

# %%
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']
